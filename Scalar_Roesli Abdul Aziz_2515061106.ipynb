# %% [markdown]
# #1. Buat variabel skalar x dan simpan suatu nilai skalar

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x = 106
x
# Out:
# 106

# %%
#tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y = 0
y
# Out:
# 0

# %%
#tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
#jumlahkan x + y
x + y
# Out:
# 106

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 1.6

# %%
#jumlahkan x_float dengan y
x_float + y
# Out:
# 1.6

# %%
#tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# # 2. Lakukan tahapan pada soal 1 dengan menggunakan tensorflow

# %%
import tensorflow as tf

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x_tf = 106

# %%
#tampilkan tipe data dari x
x_tf = tf.Variable(106, dtype=tf.int32)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=106>

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y_tf = 0

# %%
#tampilkan tipe data dari y
y_tf = tf.Variable(0, dtype=tf.int32)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=0>

# %%
#jumlahkan x + y
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=106>

# %%
#buat variabel bernama x_float dan simpan suatu nilai desimal
tf_float = 1.6

# %%
#tampilkan tipe data dari x_float
tf_float = tf.Variable(1.6, dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=1.599609375>

# %% [markdown]
# # 3. Lakukan tahapan pada soal 1 dengan menggunakan pytorch

# %%
import torch as pt

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x_pt = 106
x_pt
# Out:
# 106

# %%
# tampilkan tipe data dari x
x_pt = pt.tensor(106, dtype=pt.int32)
x_pt
# Out:
# tensor(106, dtype=torch.int32)

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y_pt = 0
y_pt
# Out:
# 0

# %%
# tampilkan tipe data dari y
y_pt = pt.tensor(0, dtype=pt.int32)
y_pt
# Out:
# tensor(0, dtype=torch.int32)

# %%
# jumlahkan x+y
x_pt + y_pt
# Out:
# tensor(106, dtype=torch.int32)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
xpt_float = 1.6

# %%
# jumlahkan x_float dengan y
ptfloat_sum = pt.add(xpt_float, y_pt)
ptfloat_sum
# Out:
# tensor(1.6000)
